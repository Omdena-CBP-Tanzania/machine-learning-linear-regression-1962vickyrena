# %% [markdown]
# ## Step 01: Import required libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Step 02: Load Dataframe

# %%
X_train = pd.read_csv(r'C:\Users\user\Omdena\machine-learning-linear-regression-carolynewambura06\X_train.csv')
X_test = pd.read_csv(r'C:\Users\user\Omdena\machine-learning-linear-regression-carolynewambura06\X_test.csv')
y_train = pd.read_csv(r'C:\Users\user\Omdena\machine-learning-linear-regression-carolynewambura06\y_train.csv')
y_test = pd.read_csv(r'C:\Users\user\Omdena\machine-learning-linear-regression-carolynewambura06\y_test.csv')

# Print shapes
print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (354, 21), Test shape: (152, 21)

# %% [markdown]
# ## Step 03: Train Linear Regreesion Model

# %%
from sklearn.linear_model import LinearRegression

# Initialize the Linear Regression model
model = LinearRegression()

# Train the model on training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
## Step 04: Make Predictions
# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[28.7076458 ],
#        [35.88434003],
#        [16.72701609],
#        [24.96758958],
#        [18.78548806],
#        [23.68895586],
#        [16.86991392],
#        [14.32254262],
#        [23.06502716],
#        [18.55021981],
#        [24.74096883],
#        [18.50518054],
#        [-6.82708556],
#        [22.29708068],
#        [19.26185139],
#        [26.14042112],
#        [19.41309134],
#        [ 5.73163496],
#        [40.01958064],
#        [17.51510057],
#        [29.66289489],
#        [29.78167768],
#        [10.41640838],
#        [22.31788154],
#        [18.05076452],
#        [16.03385619],
#        [23.71580216],
#        [14.34916035],
#        [21.57000207],
#        [17.27831351],
#        [22.30882242],
#        [25.19523165],
#        [25.22720781],
#        [18.51209653],
#        [16.65708125],
#        [17.97857688],
#        [29.76123546],
#        [19.93017633],
#        [23.13058428],
#        [24.41420684],
#        [11.93522794],
#        [32.85243798],
#        [42.20973672],
#        [17.28706655],
#        [26.0793987 ],
#        [17.21728769],
#        [13.31671792],
#        [25.63189218],
#        [20.32275305],
#        [28.32221752],
#        [21.32021763],
#        [33.89777414],
#        [15.06686482],
#        [26.54712751],
#        [39.23396466],
#        [22.9403111 ],
#        [18.89604093],
#        [32.85804359],
#        [26.90361051],
#        [14.09593671],
#        [23.04218641],
#        [30.87528865],
#        [32.2327723 ],
#        [15.87595075],
#        [20.84682975],
#        [15.86663782],
#        [20.32994169],
#        [25.67480498],
#        [33.67232718],
#        [11.85999137],
#        [22.50740594],
#        [27.52663786],
#        [10.88484533],
#        [16.60580327],
#        [24.51284732],
#        [ 5.31491808],
#        [21.94624141],
#        [40.9941707 ],
#        [18.20196877],
#        [10.85483197],
#        [20.83715833],
#        [13.08484418],
#        [20.29839923],
#        [ 9.48373364],
#        [22.61237676],
#        [32.26870664],
#        [19.01382356],
#        [25.59855144],
#        [29.11058147],
#        [20.32639278],
#        [25.63628649],
#        [ 5.45460092],
#        [20.40722656],
#        [17.42225269],
#        [14.29305854],
#        [21.07600841],
#        [24.89966537],
#        [-0.33174309],
#        [13.53435589],
#        [15.64875621],
#        [24.18934335],
#        [25.17888174],
#        [10.83633256],
#        [19.17518238],
#        [22.07324584],
#        [12.05719333],
#        [18.01897099],
#        [25.495039  ],
#        [20.60910263],
#        [24.15513505],
#        [ 7.44526099],
#        [18.9783242 ],
#        [21.54963239],
#        [29.19327138],
#        [32.67633833],
#        [15.15191432],
#        [36.16691977],
#        [12.43097475],
#        [19.03384308],
#        [26.18919721],
#        [17.03411082],
#        [26.04152456],
#        [ 3.21120902],
#        [22.00331807],
#        [27.83706228],
#        [23.13756206],
#        [25.29085575],
#        [35.18672295],
#        [20.80849066],
#        [38.1469707 ],
#        [13.15020077],
#        [25.03128723],
#        [17.25206381],
#        [18.72855688],
#        [10.36090924],
#        [21.06613318],
#        [22.09770564],
#        [32.60471369],
#        [29.93063397],
#        [14.9163651 ],
#        [16.3272573 ],
#        [29.52775319],
#        [25.03611424],
#        [16.0466517 ],
#        [ 6.1407813 ],
#        [26.37346302],
#        [23.58230159],
#        [17.31178918],
#        [12.86434915],
#        [40.33969326],
#        [16.54726259],
#        [18.20027735]])
